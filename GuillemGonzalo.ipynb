# %% [markdown]
# Import Libraries

# %%
from app.data.zip_manager import ZipExtractor

# %% [markdown]
# Decompress Files

# %%
extractor = ZipExtractor()

# Extract from origin to destination
extractor.extract("data_compressed/melanoma_test_data.zip", "data/melanoma_test_data")
extractor.extract("data_compressed/melanoma_train_data_benign.zip", "data/melanoma_train_data_benign")
extractor.extract("data_compressed/melanoma_train_data_malignant.zip", "data/melanoma_train_data_malignant")
# Out:
# 2026-03-28 20:50:50,922 - INFO - Starting decompression of 'melanoma_test_data.zip' into 'data/melanoma_test_data'...
# 2026-03-28 20:50:51,169 - INFO - Decompression completed successfully. Total files: 2003
# 2026-03-28 20:50:51,170 - INFO - Starting decompression of 'melanoma_train_data_benign.zip' into 'data/melanoma_train_data_benign'...
# 2026-03-28 20:50:51,819 - INFO - Decompression completed successfully. Total files: 6290
# 2026-03-28 20:50:51,820 - INFO - Starting decompression of 'melanoma_train_data_malignant.zip' into 'data/melanoma_train_data_malignant'...
# 2026-03-28 20:50:52,503 - INFO - Decompression completed successfully. Total files: 5591
